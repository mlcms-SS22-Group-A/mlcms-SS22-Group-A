# %%
# import required libraries
import sympy as sy

from utils import plot_bifurcation_diagram

# %load_ext autoreload
# %autoreload 2

# %%
# define symbols for equations
x, alpha = sy.symbols("x, alpha")

# %%
# Equation 6 plot
fig = plot_bifurcation_diagram(alpha - x**2, x, alpha, (-1, 1), "1")
#fig.save("task2_eq6"+ ".pdf")

# %%
# Equation 7 plot
fig2= plot_bifurcation_diagram(alpha - 2*x**2 - 3, x,alpha, (1, 5), "2")
#fig2.save("task2_eq7"+ ".pdf")
