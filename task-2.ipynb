# %%
# import required libraries
from utils import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# define symbols for equations
x, alpha = sy.symbols("x, alpha")

# %%
# Equation 6 plot
plot_bifurcation_diagram(alpha - x**2, x, (-1, 1))

# %%
# Equation 7 plot
plot_bifurcation_diagram(alpha - 2*x**2 - 3, x, (1, 5))
