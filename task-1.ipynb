# %% [markdown]
# # Imports

# %%
# import required libraries
from task_1 import *

# %load_ext autoreload
# %autoreload 2

# %%
# define notebook parameters
w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]

# %%
# create a list containing different parameters
alphas = [-2, -0.25, 1, 0.25, 2]
task_1_plot_reconstructions(X, Y, alphas, False) # set False to True if you want to save the figures
