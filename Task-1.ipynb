# %% [raw]
# Import everything here

# %%
from task_1 import *
from task1 import *
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Load the data linear_function_data.txt and approximate with a linear function

# %%
X = dataloader("linear_function_data.txt")
p = approximate_lstsq(X)
process_data_and_show(X, p)

# %% [markdown]
# Load data nonlinear_function_data and approximate with  a  linear function

# %%
X = dataloader("nonlinear_function_data.txt")
p = approximate_lstsq(X)
process_data_and_show(X, p)

# %%
approximate_with_radial_basisfunc(X, 60, 1)

# %% [markdown]
# Too big values of cond leads to flattening !!
